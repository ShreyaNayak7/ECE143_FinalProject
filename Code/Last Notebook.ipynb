# %% [markdown]
# <h1><center>Analysis of Government Expenditure</center></h1>

# %% [markdown]
# **Trends in Government Expenditure over the years**
#
# (Please refer to the Readme for data sources).<br/>
# It can be seen that the Government Expenditure has increased over the years.<br/>
# The lines for a few countries are broken due to missing data.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from bokeh import io
io.output_notebook()
import gov_exp_vs_year_script
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="935ef773-c529-4a95-971b-340eec8d0a72">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="4b3fb9ed-bc93-44bd-98d8-435e157b7fca"></div>

# %% [markdown]
# **Comparison of countries on Government Expenditure per capita (US$)**
#
# It can be seen that European countries spend the most.

# %%
# %matplotlib inline
import folium_choropleth_govt_exp_script
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Comparison of countries based on their priorities**
#
# It can be seen that developed countries spend more on social protection whereas the developing coiuntries spend more on education.

# %%
# %matplotlib notebook
import priority_bar_script
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# **Life Expectancy versus Health Expenditure**

# %%
# %matplotlib notebook
import hl_exp_vs_life_exp_script
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Literacy Rate versus Education Expenditure**

# %%
import ed_exp_vs_lit_rate_script
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Happiness Rank versus Standard of living (GDP Per Capita)**

# %%
# %matplotlib notebook
import gdp_pcapita_vs_hap_rank_script
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Poverty Rate versus Social Expenditure**

# %%
# %matplotlib notebook
import social_exp_vs_pov_script
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# **End of Notebook**
